# %%
import pandas as pd
import numpy as np
import os

_root = os.getcwd().replace("scripts", "")
print(_root)
_data = os.path.join(_root, "datasets", "scraped")
# Out:
# /Users/michaelcullen/Documents/GitHub/StockAnalyserAndPredictor/

# %%
# df = pd.read_csv(os.path.join(_root, "datasets", "crypto", "BTCUSDT-trades-2021-11.csv"))
# df

# %%
df2 = pd.read_csv(os.path.join(_root, "datasets", "crypto", "BTCUSDT-1m-2021-11.csv"))
df2
# Out:
#        1635724800000  61299.81000000  61339.73000000  61284.28000000  \
# 0      1635724860000        61295.42        61333.58        61276.57
# 1      1635724920000        61296.61        61338.99        61204.82
# 2      1635724980000        61338.93        61399.93        61229.92
# 3      1635725040000        61245.12        61252.12        61115.33
# 4      1635725100000        61243.61        61319.28        61236.10
# ...              ...             ...             ...             ...
# 43194  1638316500000        57008.36        57012.79        56970.37
# 43195  1638316560000        56980.48        57010.45        56980.00
# 43196  1638316620000        57000.01        57011.92        56980.00
# 43197  1638316680000        56992.94        57005.00        56980.00
# 43198  1638316740000        56991.48        57012.20        56835.92
#
#        61295.43000000  36.97964000  1635724859999  2267395.10970710  1171  \
# ...

# %%
df2.columns = ["time", "open", "high", "low", "close", "volume", "close_time", "quote_asset_volume", "number_of_trades", "taker_buy_base_asset_volume", "taker_buy_quote_asset_volume", "ignore"]
df2["time"] = df2["time"] * 1000000
df2["close_time"] = df2["close_time"] * 1000000
df2
# Out:
#                       time      open      high       low     close    volume  \
# 0      1635724860000000000  61295.42  61333.58  61276.57  61296.60  16.79986
# 1      1635724920000000000  61296.61  61338.99  61204.82  61338.99  68.16703
# 2      1635724980000000000  61338.93  61399.93  61229.92  61245.11  29.34522
# 3      1635725040000000000  61245.12  61252.12  61115.33  61243.62  71.52817
# 4      1635725100000000000  61243.61  61319.28  61236.10  61310.94  25.59143
# ...                    ...       ...       ...       ...       ...       ...
# 43194  1638316500000000000  57008.36  57012.79  56970.37  56980.48  15.84978
# 43195  1638316560000000000  56980.48  57010.45  56980.00  57000.01  13.37989
# 43196  1638316620000000000  57000.01  57011.92  56980.00  56992.95  15.47391
# 43197  1638316680000000000  56992.94  57005.00  56980.00  56981.67   6.92027
# 43198  1638316740000000000  56991.48  57012.20  56835.92  56950.56  33.14137
#
# ...

# %%
df3 = df2.copy()
df3 = df3[["time", "open", "high", "low", "close", "volume", "close_time", "quote_asset_volume", "number_of_trades", "taker_buy_base_asset_volume", "taker_buy_quote_asset_volume"]]
df3["time"] = pd.to_datetime(df3["time"], infer_datetime_format=True)
df3["close_time"] = pd.to_datetime(df3["close_time"], infer_datetime_format=True)

df3
# Out:
#                      time      open      high       low     close    volume  \
# 0     2021-11-01 00:01:00  61295.42  61333.58  61276.57  61296.60  16.79986
# 1     2021-11-01 00:02:00  61296.61  61338.99  61204.82  61338.99  68.16703
# 2     2021-11-01 00:03:00  61338.93  61399.93  61229.92  61245.11  29.34522
# 3     2021-11-01 00:04:00  61245.12  61252.12  61115.33  61243.62  71.52817
# 4     2021-11-01 00:05:00  61243.61  61319.28  61236.10  61310.94  25.59143
# ...                   ...       ...       ...       ...       ...       ...
# 43194 2021-11-30 23:55:00  57008.36  57012.79  56970.37  56980.48  15.84978
# 43195 2021-11-30 23:56:00  56980.48  57010.45  56980.00  57000.01  13.37989
# 43196 2021-11-30 23:57:00  57000.01  57011.92  56980.00  56992.95  15.47391
# 43197 2021-11-30 23:58:00  56992.94  57005.00  56980.00  56981.67   6.92027
# 43198 2021-11-30 23:59:00  56991.48  57012.20  56835.92  56950.56  33.14137
#
# ...
